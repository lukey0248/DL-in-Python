# %%
import numpy as np

# %%
a = np.random.randn(5)

# %%
a
# Out:
# array([ 0.14767922,  0.93538621,  0.60046108, -0.64956536, -0.74210761])

# %%
expa = np.exp(a)

# %%
expa
# Out:
# array([ 1.159141  ,  2.54819741,  1.82295914,  0.52227273,  0.4761094 ])

# %%
answer = expa / expa.sum()

# %%
answer
# Out:
# array([ 0.17754601,  0.39030823,  0.27922325,  0.07999668,  0.07292583])

# %%
answer.sum()
# Out:
# 1.0

# %%
A = np.random.randn(100, 5)

# %%
A
# Out:
# array([[  3.35164839e-01,   1.63889738e+00,  -5.90552448e-01,
#          -2.66876952e+00,   4.33799398e-01],
#        [ -6.26477782e-01,  -1.96455252e+00,  -6.76176941e-01,
#          -5.12336588e-01,  -4.87051516e-01],
#        [  6.63745922e-02,  -1.13091364e+00,  -8.41473668e-01,
#          -2.69967375e+00,   9.00723738e-01],
#        [  6.34176266e-02,   7.02220424e-01,   9.36724858e-01,
#          -6.16021226e-02,   5.40993335e-01],
#        [ -1.53801321e+00,  -1.52399861e+00,   3.68465195e-01,
#          -1.07631134e-01,  -1.24332204e-01],
#        [  1.46333590e+00,  -6.41351521e-01,   1.62690889e+00,
#          -1.40587383e+00,  -3.66313109e-01],
#        [ -2.46128543e-01,   9.55653779e-01,   2.51086812e-01,
#           6.05617275e-01,  -5.58458335e-01],
#        [  3.41832102e-01,   9.10015878e-01,   1.08606346e-01,
#           1.74126221e-01,   3.50122173e-01],
#        [ -2.99916098e-01,   2.18417544e-01,   1.57849539e+00,
#           9.93042324e-01,  -1.94162008e-01],
# ...

# %%
expA = np.exp(A)

# %%
expA
# Out:
# array([[  1.39817084,   5.14948846,   0.55402113,   0.06933749,
#           1.54310929],
#        [  0.53447101,   0.14021862,   0.50855753,   0.59909411,
#           0.61443538],
#        [  1.06862694,   0.32273826,   0.43107479,   0.06722744,
#           2.46138386],
#        [  1.06547172,   2.01822906,   2.55161083,   0.94025692,
#           1.71771228],
#        [  0.21480745,   0.21783909,   1.44551433,   0.89795876,
#           0.88308643],
#        [  4.32034775,   0.52658026,   5.08812244,   0.24515274,
#           0.69328569],
#        [  0.78182172,   2.6003701 ,   1.28542167,   1.83238294,
#           0.57209036],
#        [  1.40752396,   2.48436198,   1.11472345,   1.19020579,
#           1.41924093],
#        [  0.74088038,   1.24410643,   4.84765651,   2.69943455,
#           0.82352448],
#        [  2.19823551,   0.92162843,   5.69997868,   1.75337859,
#           0.48540966],
#        [  2.31418003,   1.00733289,   0.41259597,   0.65269373,
# ...

# %%
expA / expA.sum()
# Out:
# array([[  1.85998533e-03,   6.85035956e-03,   7.37013780e-04,
#           9.22395985e-05,   2.05279680e-03],
#        [  7.11006276e-04,   1.86532692e-04,   6.76533588e-04,
#           7.96974315e-04,   8.17382795e-04],
#        [  1.42159339e-03,   4.29338393e-04,   5.73458385e-04,
#           8.94326016e-05,   3.27437659e-03],
#        [  1.41739600e-03,   2.68484818e-03,   3.39440544e-03,
#           1.25082288e-03,   2.28507100e-03],
#        [  2.85758151e-04,   2.89791131e-04,   1.92296632e-03,
#           1.19455368e-03,   1.17476903e-03],
#        [  5.74735446e-03,   7.00509213e-04,   6.76872439e-03,
#           3.26126457e-04,   9.22277292e-04],
#        [  1.04005669e-03,   3.45926984e-03,   1.70999521e-03,
#           2.43761727e-03,   7.61051252e-04],
#        [  1.87242777e-03,   3.30494436e-03,   1.48291553e-03,
#           1.58332961e-03,   1.88801485e-03],
#        [  9.85592458e-04,   1.65503359e-03,   6.44883280e-03,
#           3.59105519e-03,   1.09553382e-03],
# ...

# %%
answer = expA / expA.sum()

# %%
answer.sum()
# Out:
# 1.0
